# %% [markdown]
# ---
#
# # **LAB Reúso de código para captura de datos - Inicio**
#
# ---

# %% [markdown]
# ### PARTE 1
#
# Crear una función llamada `CalcularArea`, que tenga dos argumentos `lado1` y `lado2`.
#
# La función debe retornar un mensaje que muestre el área de un cuadrilátero.
#
# Si `lado1` es igual a `lado2`, la función debe retornar `El área del cuadrado es x`, donde `x` es el área del cuadrado (`lado1*lado2`).
#
# Si `lado1` y `lado2` son diferentes, debe retornar `El area del rectángulo es x`, donde `x` es el área del rectángulo (`lado1*lado2`).
#
# Muestra el resultado que da la función, usando `print()`.
#
# Prueba usando como parámetros `10` y `20`.
#
# Prueba usando como parámetros `10` y `10`.
#
# Prueba usando parámetros nominados, y pasa primero el parámetro `lado2` con el valor de `25`, y luego pasa el parámetro `lado1` con el valor `5`.

# %%
# Declara una función, llamada CalcularArea, usando def.
# Debes especificar dos argumentos, entre paréntesis,
# separados por comas, llamados "lado1" y "lado2"
# respectivamente.

    
    # Coloca un condicional, en donde evalúes si "lado1"
    # es igual a "lado2". Si son iguales, define una variable
    # llamada "mensaje", y asígnale un F-String que diga:
    # f"El área del cuadrado es {lado1*lado2}"
    # Si no son iguales, define una variable
    # llamada "mensaje", y asígnale un F-String que diga:
    # f"El área del rectángulo es {lado1*lado2}"
    # Toma nota que la única diferencia es la palabra
    # cuadrado/rectángulo.


    
    # Se recomienda no usar return dentro de condicionales.
    # Por esa razón resolvemos el valor de retorno en el 
    # condicional, pero garantizamos que idependientemente
    # del resultado, return siempre se ejecuta.
    # Aquí, retorna el valor que tengas en "mensaje"


# Probando la función
# Imprime el valor que retorne CalcularArea, si le pasas
# como parámetros 10 y 20


# Imprime el valor que retorne CalcularArea, si le pasas
# como parámetros 10 y 10


# Imprime el valor que retorne CalcularArea, si le pasas
# parámetros nominados. "lado2" con 25, y "lado1" con 5

# %% [markdown]
# ### PARTE 2
#
# Deseas crear una función llamada `CapturarEnteroPositivo`.
#
# La función tiene un argumento, llamado `mensaje`, que es opcional. En caso de que no se proporcione un parámetro al momento de ser llamado a ejecución, deberá asignarse como mensaje `Proporciona un número:`.
#
# La función deberá realizar lo siguiente:
#
# - Deberá preguntar un dato.
# - El dato se preguntará en un ciclo infinito, que no dejará de preguntarse sino hasta que sea correcto, o que se omita respuesta.
# - Si se omite la respuesta, indica salirse del ciclo.
# - Si no se omite, deberá capturarse un número entero positivo. Se sugiera permitir la captura de 0 a 6 dígitos.
#
# Es importante aclarar que al final de ejecutar el programa, se debe mostrar la suma acumuada de todos los valores que se hayan caprturado usando la función, para lo cual se utilizará un acumulador, de naturaleza global.
#
# Probar ejecutando de la siguente manera:
#
# Ejecutar `CapturarEnteroPositivo("Dame una cifra:")` y capturar `10`.
#
# Ejecutar `CapturarEnteroPositivo()` y capturar `30`.
#
# Ejecutar `CapturarEnteroPositivo()` y capturar `Hola`, luego `-2`, luego `50`.
#
#
# Al final, imprimir el total acumulado de los valores proporcionados, que debe ser `90`.

# %%
# Importando la librería de manejo de expresiones regulares
# y definir el patrón requerido por el programa.


# Declara una variable de tipo entera, llamada "acumulado"
# que será global



# Declara una función llamada "CapturarEnteroPositivo", que tenga
# un argumento llamado "mensaje", con un valor por omisión que
# sea "Proporciona un número: ".


    
    # Especifica que quieres usar la variable "acumulado" como global

    

    
    # Inicia un ciclo infinito.


        
        # Pregunta un dato usando input; coloca como texto lo que
        # tengas en el argumento mensaje. Asigna lo preguntado a
        # una variable llamada "Numero"


        
        # Agrega un condicional. Si "Numero" es igual a nada
        # sal del ciclo infinito, usando break


        
        # Agrega un condicional. Si "Numero" no cumple con el
        # patrón de expresión regular almacenado en "patron"
        # informa que el dato no tiene formato correcto, usando
        # print, y ejecuta continue, para que vuelva a preguntar.

            

        
        # Si llegas hasta aquí, quiere decir que lo capturado tiene
        # formato de número entero. Asigna la conversión de "Numero"
        # a int, y asígnalo a una variable llamada "numero".



        # Agrega un condicional. Si "numero" es menor a cero
        # informa que el dato no puede ser negativo, usando
        # print, y ejecuta continue, para que vuelva a preguntar.


        
        # Si llega aquí, es que lo capturado pudo convertirse a
        # int. Acumula el valor de "numero", en la variable global
        # "acumulado". Luego, sal del ciclo infinito, con break.

        

        
# Ya programaste la función. Ahora falta probarla.

# Ejecuta la función "CapturarEnteroPositivo", pasándole como
# parámetro "Dame una cifra: ". Captura 10. Se demuestra que si
# se proporciona un parámetro, éstos remplazan al valor 
# por omisión.



# Ejecuta la función "CapturarEnteroPositivo" y no pases parámetros.
# Captura 30. Se demuestra que si los argumentos son opcionales y se
# omite el parámetro, la función usa el valor por omisión.



# Ejecuta la función "CapturarEnteroPositivo" y no pases parámetros.
# Captura "Hola", luego, captura -2, y luego, captura 50. 
# Se demuestra que la función valida correctamente.



# Imprime el valor acumulado en la variable "acumulado".
# Debe ser 90

# %% [markdown]
# ### PARTE 3
#
# Elabora una función llamada `HoraTemporal()`, que reciba un argumento, consistente en una hora en formato decimal, y que sea de retorno multiple; se espera que retorne dos datos enteros, uno correspondiente a las horas, y otro correspondiente a los minutos.
#
# Por ejemplo, si se proporciona el valor de `1.5` horas, retorne `1` en el valor de horas, y `30` en minutos, porque el `0.5` de una hora son `30` minutos.
#
# Las horas serán igual a convertir a entero la hora decimal. La diferencia entre la hora y la hora decimal nos dará la parte decimal de la hora, que multiplicada por 60 y convertida a entero, nos da los minutos.
#
# Si se ejecuta lo siguiente:
#
# ```
# (x,y) = HoraTemporal(1.5)
# ```
# `x` tendrá el valor de 1, y `y` de 30. `f"{x}:{y}"` Generaría `1:30`
#
# Pruébalo así, e imprime el valor de `x` y de `y`.

# %%
# Elaborar una función llamada HoraTemporal() que reciba un 
# argumento tipo float, que represente una hora en decimal
# y que retorne dos valores int: uno correspondiente a las
# horas, y el otro a los minutos.
